# %%
import sys
sys.path.append('../MCMC_main/tools')
sys.path.append('../MCMC_main')
import uncertainty_DICT
import parameters_DICT
import geometry_binary
import os,glob
import pylab
import pyfits as pf
import numpy as np
import scipy
import matplotlib.pylab as plt
import scipy.constants as c
from PyAstronomy import pyasl
from scipy import interpolate
import csv
import pickle
import pandas as pd

# %%
def scale_intensity(wave_0,
                    wave_template,
                    intensity_template,
                    wave_spec,
                    intensity_spec,
                    norm=True,
                    wave_region=100e-10,
                    wave_0_d=100e-10):
    '''
    Returns the rescaled spectrum.
    norm=True if the spectrum is normalised.
    '''
    if norm==True:
        wave_min_a     = wave_0 - (wave_0_d + wave_region)
        wave_min_b     = wave_0 - (wave_0_d)
        wave_max_a     = wave_0 + (wave_0_d)
        wave_max_b     = wave_0 + (wave_0_d + wave_region)
        index_low  = np.argmax(intensity_template[np.where((wave_template > wave_min_a) & (wave_template < wave_min_b))])
        index_high = np.argmax(intensity_template[np.where((wave_template > wave_max_a) & (wave_template < wave_max_b))])
        I_low      = (intensity_template[np.where((wave_template > wave_min_a) & (wave_template < wave_min_b))])[index_low]
        I_high     = (intensity_template[np.where((wave_template > wave_max_a) & (wave_template < wave_max_b))])[index_high]
        wave_low   = (wave_template[np.where((wave_template > wave_min_a) & (wave_template < wave_min_b))])[index_low]
        wave_high  = (wave_template[np.where((wave_template > wave_max_a) & (wave_template < wave_max_b))])[index_high]
        gradient       = (I_high - I_low) / ( wave_high - wave_low)
        intercept      = I_high - gradient * wave_high
        scaling_interp = np.poly1d(np.array([gradient, intercept]))

        intensity_spec = intensity_spec * scaling_interp(wave_spec)

    # if norm==True:
    #     wave_min_a     = wave_0 - (wave_0_d + wave_region)
    #     wave_min_b     = wave_0 - (wave_0_d)
    #     wave_max_a     = wave_0 + (wave_0_d)
    #     wave_max_b     = wave_0 + (wave_0_d + wave_region)
    #     median_I_low   = np.median(intensity_template[np.where((wave_template > wave_min_a) & (wave_template < wave_min_b))])
    #     median_I_high  = np.median(intensity_template[np.where((wave_template > wave_max_a) & (wave_template < wave_max_b))])
    #     gradient       = (median_I_high - median_I_low) / ( 2 * wave_0_d + wave_region)
    #     intercept      = median_I_high - gradient *  (wave_0 + wave_0_d + 0.5 * wave_region)
    #     scaling_interp = np.poly1d(np.array([gradient, intercept]))
    #     intensity_spec = intensity_spec * scaling_interp(wave_spec)
    #     print(gradient, intercept)
    #     plt.plot(wave_spec, intensity_spec)
    #     plt.plot(wave_template, intensity_template)
    #     plt.show()
    return intensity_spec, scaling_interp

# %%
object_id = 'TW_Cam'
datafile  = object_id+'.dat'
listfile      = object_id+'.list'
line          = 'halpha'
v_range       = 2000
what          = 'observed'

# %%
central_wavelengths = {'halpha': 6562.8e-10, 'hbeta': 4861.35e-10, 'hgamma': 4340.47e-10, 'hdelta': 4101.73e-10}
central_wavelength  = central_wavelengths[line]
wave_min            = central_wavelength - (1000*v_range/c.speed_of_light) * central_wavelength
wave_max            = central_wavelength + (1000*v_range/c.speed_of_light) * central_wavelength

# %%
###### Read in the object specific and model parameters ########################
parameters = {}
InputDir   = '../input_data/'+object_id+'/'
InputFile  = datafile
# Out:
# TW_Cam.dat

# %%
###### Create the parameter dictionary with all jet, binary, and model parameters
parameters = parameters_DICT.read_parameters(InputDir+InputFile)
parameters['BINARY']['T_inf'] = geometry_binary.T0_to_IC(parameters['BINARY']['omega'],
                                                         parameters['BINARY']['ecc'],
                                                         parameters['BINARY']['period'],
                                                         parameters['BINARY']['T0'])

parameters['OTHER']['central_wavelength'] = central_wavelength

# %%
def get_spectrum(filename, phase_value, parameters, v_range, bjd):


    datalist = glob.glob(filename)
    print(datalist)
    if len(datalist) > 0:

        # Read the data and the header is resp. 'spectrum' and 'header'
        spectrum = pf.getdata(datalist[0])
        header   = pf.getheader(datalist[0])

        crpix           = header.get('CRPIX1')-1
        crval           = header.get('CRVAL1')
        cdelt           = header.get('CDELT1')
        bvcor           = header.get('BVCOR')
        numberpoints    = len(spectrum)
        wavelengthbegin = (crval - crpix*cdelt)
        wavelengthend   = crval + (numberpoints-1)*cdelt
        wavelengths     = np.linspace(wavelengthbegin,wavelengthend,numberpoints)
        # Change from logarithmic to linear wavelength range
        wavelengthslin  = np.exp(wavelengths)
        print(wavelengthslin)
        spectrum_wave_min = min(range(len(wavelengthslin)), key = lambda j: abs(wavelengthslin[j]- (parameters['OTHER']['central_wavelength'] - 48)))
        spectrum_wave_max = min(range(len(wavelengthslin)), key = lambda j: abs(wavelengthslin[j]- (parameters['OTHER']['central_wavelength'] + 48)))
        
        print(spectrum_wave_min, spectrum_wave_max)
    
    return wavelengthslin, spectrum_wave_min

create_observed_spectra_file(object_id, parameters, InputDir)
# Out:
# 0 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*578163_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00578163_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3860.6781721
#   4026.03477693  3939.67750823]
# 0 0
# 1 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*578786_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00578786_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  2842.67643897
#   3052.02820173  2774.3000184 ]
# 0 0
# 2 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*580871_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00580871_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  4853.87562911
#   4783.22041829  4743.62305277]
# 0 0
# 3 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*584659_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00584659_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3435.36890833
#   3321.65340408  3444.62996971]
# 0 0
# 4 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*595925_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00595925_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  4132.99384837
#   4008.91785353  4150.19705498]
# 0 0
# 5 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*596969_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00596969_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3933.67384624
#   3749.34777424  4057.53955724]
# 0 0
# 6 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*597800_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00597800_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3674.38294841
#   3719.4797827   3824.13968178]
# 0 0
# 7 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/
HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [            nan             nan             nan ...,   9546.17662692
#    9700.98698908  10105.63786773]
# 0 0
# 36 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*893516_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00893516_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  8754.01476582
#   9066.08331144  9381.3456196 ]
# 0 0
# 37 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*904076_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00904076_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3944.56895565
#   4018.21560572  3924.33990152]
# 0 0
# 38 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*904716_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00904716_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3813.6278831
#   3781.55628275  3962.17415048]
# 0 0
# 39 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*907085_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00907085_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3226.7981004
#   3264.17659313  3503.70073128]
# 0 0
# 40 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*908139_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00908139_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  5803.07648298
#   5799.19251713  6089.90328771]
# 0 0
# 41 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*908725_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00908725_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# [           nan            nan            nan ...,  3360.06370556
#   3540.48319373  3558.3002981 ]
# 0 0

# %%
def create_observed_spectra_file(object_id, parameters, InputDir):

    data_list = pd.read_csv(InputDir+object_id+'.list', delimiter=' ', names=['ID', 'full_date', 'object_id', 'bjd', 'bvcor', 'program_id', 'exposure_time', 'something', 'something_else', 'date'])
    
    phases    = ( (data_list.bjd - parameters['BINARY']['T_inf']) / parameters['BINARY']['period'] ) % 1

    filenames = [ '/lhome/dylanb/astronomy/objects/survey2020/'+object_id+'/*'+str(filenumber)+'_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits' for filenumber in data_list.ID]

    for (spectrum, filename) in enumerate(filenames):
        wavelength_spectrum, spectrum = get_spectrum(filename, phases[spectrum], parameters, v_range, data_list.bjd[spectrum])


    return
# Out:
# 0 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*578163_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00578163_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 1 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*578786_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00578786_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 2 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*580871_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00580871_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 3 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*584659_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00584659_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 4 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*595925_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00595925_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 5 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*596969_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00596969_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 6 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*597800_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00597800_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 7 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*606978_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00606978_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 8 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*608379_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00608379_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 9 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*611696_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00611696_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 10 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*612363_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00612363_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 11 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*619230_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00619230_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 12 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*649671_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00649671_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 13 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*651297_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00651297_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 14 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*653565_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00653565_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 15 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*661743_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00661743_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 16 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*665173_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00665173_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 17 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*696536_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00696536_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 18 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*737505_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00737505_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 19 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*753504_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00753504_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 20 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*759974_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00759974_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 21 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*761803_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00761803_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 22 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*762100_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00762100_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 23 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*763266_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00763266_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 24 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*769359_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00769359_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 25 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*777291_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00777291_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 26 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*834364_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00834364_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 27 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*835486_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00835486_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 28 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*842747_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00842747_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 29 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*858500_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00858500_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 30 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*860566_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00860566_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 31 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*863942_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00863942_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 32 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*867649_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00867649_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 33 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*868853_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00868853_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 34 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*870410_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00870410_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 35 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*892634_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00892634_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 36 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*893516_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00893516_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 37 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*904076_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00904076_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 38 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*904716_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00904716_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 39 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*907085_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00907085_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 40 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*908139_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00908139_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
# 41 /lhome/dylanb/astronomy/objects/survey2020/TW_Cam/*908725_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits
# ['/lhome/dylanb/astronomy/objects/survey2020/TW_Cam/00908725_HRF_OBJ_ext_CosmicsRemoved_log_merged_c.fits']
# 0 0
